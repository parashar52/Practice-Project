# %% [markdown]
# # World Happiness Project

# %% [markdown]
# # Project Description

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness.
# The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update.
# The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at
# an event celebrating International Day of Happiness on March 20th. The report continues
# to gain global recognition as governments, organizations and civil society increasingly
# use happiness indicators to inform their policy-making decisions. Leading experts across
# fields – economics, psychology, survey analysis, national statistics, health, public policy and
# more – describe how measurements of well-being can be used effectively to assess the progress of nations.
# The reports review the state of happiness in the world today and show how the new science of happiness
# explains personal and national variations in happiness.

# %% [markdown]
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity,
# Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in
# each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the
# unexplained value for each country.
# The Dystopia Residual is already provided in the dataset.
# If you add all these factors up, you get the happiness score so it might be un-reliable to
# model them to predict Happiness Scores

# %% [markdown]
# GDP per capita,Family,life Expectancy,freedom,generousity,trust,government corruption are tthe following attributes
# which is used in calculating the happiness score of the country

# %% [markdown]
# # importing required labraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df=pd.read_csv('happiness_score.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#Now we want to see the top 5 columns
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Now checking the shape
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Checking the data ypes of data
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [raw]
# There are three types of data are present namely-object,int,float.

# %%
#Checking the null values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [raw]
# As we can see there is no null value is present in the dataset

# %%
#To get overview of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#To check the no of unique values in each column
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
#Checking the value counts in each column
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
df['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# # Statistical summary of the dataset

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# The looks normal,only large gap between 75% and max in happiness rank so might be outliers present in it.

# %% [markdown]
# # Exploring the data

# %%
#Check the value counts of happiness score
df['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
#Checking if there duplicated values are present
df.duplicated().sum()
# Out:
# 0

# %%
#Now check the duplicated values for all rhe columns
df.duplicated().sum()
# Out:
# 0

# %% [raw]
# Basically the happiness score of a country depend on
# Gdp,Generousity,trust,govt corruption
# Freedom
# Life Expectancy

# %% [markdown]
# # Data Visualization

# %% [markdown]
# To check missing values

# %%
#Let's visualize it using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Check correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
#Now visualize it using the heatmap
plt.figure(figsize=(8,6))
sns.heatmap(dfcor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# To check the skewness

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Plotting the outliers

# %% [markdown]
# Univariate Analysis

# %%
df['Happiness Score'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Economy (GDP per Capita)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Health (Life Expectancy)'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see that there are no ouliers present in Happiness score,gdp or health expectancy column

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.53;0.110714x0.35)
# Happiness Score                  AxesSubplot(0.257857,0.53;0.110714x0.35)
# Standard Error                   AxesSubplot(0.390714,0.53;0.110714x0.35)
# Economy (GDP per Capita)         AxesSubplot(0.523571,0.53;0.110714x0.35)
# Family                           AxesSubplot(0.656429,0.53;0.110714x0.35)
# Health (Life Expectancy)         AxesSubplot(0.789286,0.53;0.110714x0.35)
# Freedom                             AxesSubplot(0.125,0.11;0.110714x0.35)
# Trust (Government Corruption)    AxesSubplot(0.257857,0.11;0.110714x0.35)
# Generosity                       AxesSubplot(0.390714,0.11;0.110714x0.35)
# Dystopia Residual                AxesSubplot(0.523571,0.11;0.110714x0.35)
# dtype: object

# %% [markdown]
# # To check distribution of skewness

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %% [markdown]
# Bivariate Analysis

# %%
plt.scatter(df['Happiness Score'],df['Freedom'])

# %%
plt.scatter(df['Happiness Score'],df['Generosity'])

# %%
plt.scatter(df['Happiness Score'],df['Trust (Government Corruption)'])

# %%
plt.scatter(df['Happiness Score'],df['Family'])

# %%
plt.scatter(df['Happiness Score'],df['Economy (GDP per Capita)'])

# %%
plt.scatter(df['Happiness Score'],df['Standard Error'])

# %% [markdown]
# From above visualization we can see that freedom,life expectancy,gdp,family,trust.generousity involves in the
# happiness score of a country

# %%
sns.pairplot(df)

# %%
gdpby_region=df.groupby('Region')['Economy (GDP per Capita)'].sum()

# %%
gdpby_region
# Out:
# Region
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: Economy (GDP per Capita), dtype: float64

# %% [markdown]
# Through that we can find out the which part of world/region contibute how much in world's gdp
# western,central or eastern europe contribute more in the gdp which is 20.4%
# Then in second place we have middle east and northern africa which have 16% contribution
# Then rest of the countries lies like Sothern Asia,North America and many more
# With 2% North America is the lowest contribution to the world's gdp

# %%
Total_country=df.groupby('Region')['Country'].count()

# %%
Total_country
# Out:
# Region
# Australia and New Zealand           2
# Central and Eastern Europe         29
# Eastern Asia                        6
# Latin America and Caribbean        22
# Middle East and Northern Africa    20
# North America                       2
# Southeastern Asia                   9
# Southern Asia                       7
# Sub-Saharan Africa                 40
# Western Europe                     21
# Name: Country, dtype: int64

# %% [markdown]
# From that we can get the exact number of countries in the region
# Like in sub saharan africa there are 40 countries
# Also in middle east and northern africa there are 20 countries
# In central and Eastern Europe we have 29 countries

# %%
Corruption=df.groupby('Region')['Trust (Government Corruption)'].mean()
Corruption
# Out:
# Region
# Australia and New Zealand          0.392795
# Central and Eastern Europe         0.086674
# Eastern Asia                       0.127695
# Latin America and Caribbean        0.117172
# Middle East and Northern Africa    0.181702
# North America                      0.244235
# Southeastern Asia                  0.151276
# Southern Asia                      0.102536
# Sub-Saharan Africa                 0.123878
# Western Europe                     0.231463
# Name: Trust (Government Corruption), dtype: float64

# %% [markdown]
# From above visualization we can see that Central
# and eastern europe has least corruption

# %% [markdown]
# Conclusion:
# From above visualization we can see that happiness score is directly proportional to
# Gdp per capita, Less corruption
# Freedom of sppech
# Life expectancy
# Family and many more factors
# There is no link of happiness with the standard error, residual dystopia
# The country with have less corruption increase in the happiness index

# %% [markdown]
# There are 158 countries with europe tops the happiness index, having good gdp per capita, greater life expectancy than the
# sub saharan africa region
# Also corruption is very less in europe region
